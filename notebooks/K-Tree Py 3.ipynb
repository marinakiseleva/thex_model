# %%
mag_cols = ['GALEXAIS_FUV', 'GALEXAIS_NUV', 
         'GALEXAIS_FUV.b', 'GALEXAIS_e_FUV.b', 'GALEXAIS_NUV.b',
        'GALEXAIS_e_NUV.b', 'GALEXAIS_FUV.a', 'GALEXAIS_e_FUV.a', 'GALEXAIS_NUV.a',
        'GALEXAIS_e_NUV.a', 'GALEXAIS_FUV.4', 'GALEXAIS_e_FUV.4', 'GALEXAIS_NUV.4', 
        'GALEXAIS_e_NUV.4', 'GALEXAIS_FUV.6', 'GALEXAIS_e_FUV.6', 'GALEXAIS_NUV.6', 
        'GALEXAIS_e_NUV.6',
        'AllWISE_W1mag', 'AllWISE_e_W1mag', 'AllWISE_W2mag', 'AllWISE_e_W2mag',
           'AllWISE_W3mag', 'AllWISE_e_W3mag', 'AllWISE_W4mag', 'AllWISE_e_W4mag', 
        'PS1_gmag' ,
        'PS1_gmagStd', 'PS1_b_gmag' ,'PS1_B_gmag',
        'PS1_gKmag' ,
        'PS1_rmag',
        'PS1_rmagStd', 'PS1_b_rmag' ,'PS1_B_rmag',
        'PS1_rKmag' ,
        'PS1_imag' ,
        'PS1_imagStd', 'PS1_b_imag', 'PS1_B_imag',
        'PS1_iKmag' ,
        'PS1_zmag' ,
        'PS1_zmagStd', 'PS1_b_zmag', 'PS1_B_zmag',
        'PS1_zKmag' ,
        'PS1_ymag',
        'PS1_ymagStd', 'PS1_b_ymag', 'PS1_B_ymag',
        'PS1_yKmag' 
]

flux_cols = ['GALEXAIS_Fflux', 'GALEXAIS_Nflux']

external_cols = ['AllWISE_Jmag', 'AllWISE_Hmag', 'AllWISE_Kmag']

source_size = ['GALEXAIS_Fima',
'GALEXAIS_Nima',
'GALEXAIS_Fr',
'GALEXAIS_Nr']

quality_photometry= ['AllWISE_snr1',
'AllWISE_chi2W1',
'AllWISE_snr2',
'AllWISE_chi2W2',
'AllWISE_snr3',
'AllWISE_chi2W3',
'AllWISE_snr4',
'AllWISE_chi2W4',
'AllWISE_chi2']
extinction_rates= ['GALEXAIS_E_B-V_',
'MWExt_FUV_PS' ,
'MWExt_NUV_PS' ,
'MWExt_FUV_Y',
'MWExt_NUV_Y',
'MWExt_u' ,
'MWExt_g' ,
'MWExt_r' ,
'MWExt_i' ,
'MWExt_z' ,
'MWExt_J' ,
'MWExt_H' ,
'MWExt_Ks' ,
'MWExt_W1' ,
'MWExt_W2' ,
'MWExt_W3' ,
'MWExt_W4' ]


cols = mag_cols + flux_cols + external_cols + source_size + quality_photometry + extinction_rates

# %%
from models.ktrees_model.ktrees_model import KTreesModel
# %matplotlib inline 
ktree = KTreesModel(
         cols = cols,
         transform_features = True,
#          pca = 5,
         incl_redshift = True,
         num_runs = 1,
         subsample = 200,
#          top_classes = 10,
         naive = False)
ktree.run_model()
# Out:
# Data Filters
# ------------------
# num_runs : 1
# test_on_train : False
# folds : None
# data_split : 0.3
# top_classes : 10
# one_all : None
# subsample : 200
# transform_features : True
# transform_labels : False
# incl_redshift : True
# pca : 5
# naive : False
#
# Features
# ------------------
# GALEXAIS_FUV, GALEXAIS_NUV, GALEXAIS_FUV.b, GALEXAIS_NUV.b, GALEXAIS_FUV.a, GALEXAIS_NUV.a, GALEXAIS_FUV.4, GALEXAIS_NUV.4, GALEXAIS_FUV.6, GALEXAIS_NUV.6, AllWISE_W1mag, AllWISE_W2mag, AllWISE_W3mag, AllWISE_W4mag, PS1_gmag, PS1_gmagStd, PS1_b_gmag, PS1_B_gmag, PS1_gKmag, PS1_rmag, PS1_rmagStd, PS1_b_rmag, PS1_B_rmag, PS1_rKmag, PS1_imag, PS1_imagStd, PS1_b_imag, PS1_B_imag, PS1_iKmag, PS1_zmag, PS1_zmagStd, PS1_b_zmag, PS1_B_zmag, PS1_zKmag, PS1_ymag, PS1_ymagStd, PS1_b_ymag, PS1_B_ymag, PS1_yKmag, GALEXAIS_Fflux, GALEXAIS_Nflux, AllWISE_Jmag, AllWISE_Hmag, AllWISE_Kmag, GALEXAIS_Fima, GALEXAIS_Nima, GALEXAIS_Fr, GALEXAIS_Nr, AllWISE_snr1, AllWISE_chi2W1, AllWISE_snr2, AllWISE_chi2W2, AllWISE_snr3, AllWISE_chi2W3, AllWISE_snr4, AllWISE_chi2W4, AllWISE_chi2, GALEXAIS_E_B-V_, MWExt_FUV_PS, MWExt_NUV_PS, MWExt_FUV_Y, MWExt_NUV_Y, MWExt_u, MWExt_g, MWExt_r, MWExt_i, MWExt_z, MWExt_J, MWExt_H, MWExt_Ks, MWExt_W1, MWExt_W2, MWExt_W3, MWExt_W4
#
# PCA Analysis: Explained Variance Ratio
# [0.46118287 0.15659491 0.12745803 0.0428086  0.03029777]
# [0 1 2 3 4 5 6 7 8]
# ['CC, I, Ib', 'CC, I, Ic', 'CC, II', 'CC, II, II P', 'CC, II, IIb', 'CC, II, IIn', 'I, I Pec, Ia, Ia Pec, Ia-91T', 'I, Ia', 'I, Ib/c']
# Getting model for class CC
# Best score
# -0.22214034540038638
# Params for class CC
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 3, 'min_samples_split': 0.2, 'min_weight_fraction_leaf': 0.001, 'presort': False, 'random_state': None, 'splitter': 'random'}
# Getting model for class I
# Best score
# -0.2390028651934874
# Params for class I
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 3, 'min_samples_split': 0.2, 'min_weight_fraction_leaf': 0.001, 'presort': False, 'random_state': None, 'splitter': 'random'}
# Getting model for class I Pec
# Best score
# -0.043795620437956206
# Params for class I Pec
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# Getting model for class II
# Best score
# -0.2299529598898573
# Params for class II
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 3, 'min_samples_split': 0.2, 'min_weight_fraction_leaf': 0.01, 'presort': False, 'random_state': None, 'splitter': 'random'}
# Getting model for class II P
# Best score
# -0.20100508412134843
# Params for class II P
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 0.01, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'random'}
# Getting model for class IIb
# Best score
# -0.0364963503649635
# Params for class IIb
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# Getting model for class IIn
# Best score
# -0.08759124087591241
# Params for class IIn
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# Getting model for class Ia
# Best score
# -0.25015909713824397
# Params for class Ia
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 3, 'min_samples_split': 0.01, 'min_weight_fraction_leaf': 0.001, 'presort': False, 'random_state': None, 'splitter': 'random'}
# Getting model for class Ia Pec
# Best score
# -0.046228710462287104
# Params for class Ia Pec
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# Getting model for class Ia-91T
# Best score
# -0.0535279805352798
# Params for class Ia-91T
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# Getting model for class Ib
# Best score
# -0.0705596107055961
# Params for class Ib
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# Getting model for class Ib/c
# Best score
# -0.02919527907051614
# Params for class Ib/c
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'best'}
# Getting model for class Ic
# Best score
# -0.036492845767266024
# Params for class Ic
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 0.01, 'min_weight_fraction_leaf': 0, 'presort': False, 'random_state': None, 'splitter': 'random'}
