# %% [markdown]
# Define data columns to pass into model

# %%
mag_cols = ['GALEXAIS_FUV', 'GALEXAIS_NUV', 
         'GALEXAIS_FUV.b', 'GALEXAIS_e_FUV.b', 'GALEXAIS_NUV.b',
        'GALEXAIS_e_NUV.b', 'GALEXAIS_FUV.a', 'GALEXAIS_e_FUV.a', 'GALEXAIS_NUV.a',
        'GALEXAIS_e_NUV.a', 'GALEXAIS_FUV.4', 'GALEXAIS_e_FUV.4', 'GALEXAIS_NUV.4', 
        'GALEXAIS_e_NUV.4', 'GALEXAIS_FUV.6', 'GALEXAIS_e_FUV.6', 'GALEXAIS_NUV.6', 
        'GALEXAIS_e_NUV.6',
        'AllWISE_W1mag', 'AllWISE_e_W1mag', 'AllWISE_W2mag', 'AllWISE_e_W2mag',
           'AllWISE_W3mag', 'AllWISE_e_W3mag', 'AllWISE_W4mag', 'AllWISE_e_W4mag', 
        'PS1_gmag' ,
        'PS1_gmagStd', 'PS1_b_gmag' ,'PS1_B_gmag',
        'PS1_gKmag' ,
        'PS1_rmag',
        'PS1_rmagStd', 'PS1_b_rmag' ,'PS1_B_rmag',
        'PS1_rKmag' ,
        'PS1_imag' ,
        'PS1_imagStd', 'PS1_b_imag', 'PS1_B_imag',
        'PS1_iKmag' ,
        'PS1_zmag' ,
        'PS1_zmagStd', 'PS1_b_zmag', 'PS1_B_zmag',
        'PS1_zKmag' ,
        'PS1_ymag',
        'PS1_ymagStd', 'PS1_b_ymag', 'PS1_B_ymag',
        'PS1_yKmag' 
]

flux_cols = ['GALEXAIS_Fflux', 'GALEXAIS_Nflux']

external_cols = ['AllWISE_Jmag', 'AllWISE_Hmag', 'AllWISE_Kmag']

source_size = ['GALEXAIS_Fima',
'GALEXAIS_Nima',
'GALEXAIS_Fr',
'GALEXAIS_Nr']

quality_photometry= ['AllWISE_snr1',
'AllWISE_chi2W1',
'AllWISE_snr2',
'AllWISE_chi2W2',
'AllWISE_snr3',
'AllWISE_chi2W3',
'AllWISE_snr4',
'AllWISE_chi2W4',
'AllWISE_chi2']
extinction_rates= ['GALEXAIS_E_B-V_',
'MWExt_FUV_PS' ,
'MWExt_NUV_PS' ,
'MWExt_FUV_Y',
'MWExt_NUV_Y',
'MWExt_u' ,
'MWExt_g' ,
'MWExt_r' ,
'MWExt_i' ,
'MWExt_z' ,
'MWExt_J' ,
'MWExt_H' ,
'MWExt_Ks' ,
'MWExt_W1' ,
'MWExt_W2' ,
'MWExt_W3' ,
'MWExt_W4' ]




cols = mag_cols + flux_cols + external_cols + source_size + quality_photometry + extinction_rates

# %%
from models.kde_model.kde_model import KDEModel
# %matplotlib inline 

kde = KDEModel(
         cols = cols,
         folds = 3, 
         transform_features = True,
         top_classes = 14,
         incl_redshift = True,
         pca = 5,
         num_runs = 1,
         naive = False, # False -> Multi-dimensional kernel
         )
kde.run_model()
# Out:
# Data Filters
# ------------------
# num_runs : 1
# test_on_train : False
# folds : 3
# data_split : 0.3
# hierarchical_model : False
# top_classes : 14
# one_all : None
# subsample : None
# transform_features : True
# transform_labels : True
# incl_redshift : True
# pca : 5
# naive : False
#
# Features
# ------------------
# GALEXAIS_FUV, GALEXAIS_NUV, GALEXAIS_FUV.b, GALEXAIS_NUV.b, GALEXAIS_FUV.a, GALEXAIS_NUV.a, GALEXAIS_FUV.4, GALEXAIS_NUV.4, GALEXAIS_FUV.6, GALEXAIS_NUV.6, AllWISE_W1mag, AllWISE_W2mag, AllWISE_W3mag, AllWISE_W4mag, PS1_gmag, PS1_gmagStd, PS1_b_gmag, PS1_B_gmag, PS1_gKmag, PS1_rmag, PS1_rmagStd, PS1_b_rmag, PS1_B_rmag, PS1_rKmag, PS1_imag, PS1_imagStd, PS1_b_imag, PS1_B_imag, PS1_iKmag, PS1_zmag, PS1_zmagStd, PS1_b_zmag, PS1_B_zmag, PS1_zKmag, PS1_ymag, PS1_ymagStd, PS1_b_ymag, PS1_B_ymag, PS1_yKmag, GALEXAIS_Fflux, GALEXAIS_Nflux, AllWISE_Jmag, AllWISE_Hmag, AllWISE_Kmag, GALEXAIS_Fima, GALEXAIS_Nima, GALEXAIS_Fr, GALEXAIS_Nr, AllWISE_snr1, AllWISE_chi2W1, AllWISE_snr2, AllWISE_chi2W2, AllWISE_snr3, AllWISE_chi2W3, AllWISE_snr4, AllWISE_chi2W4, AllWISE_chi2, GALEXAIS_E_B-V_, MWExt_FUV_PS, MWExt_NUV_PS, MWExt_FUV_Y, MWExt_NUV_Y, MWExt_u, MWExt_g, MWExt_r, MWExt_i, MWExt_z, MWExt_J, MWExt_H, MWExt_Ks, MWExt_W1, MWExt_W2, MWExt_W3, MWExt_W4
#
#
# Constructing Class Hierarchy Tree...
# Node: Ia Pec has already been assigned parent: I Pec
# Node: Ia-02cx has already been assigned parent: Ia
# Node: Ia-HV has already been assigned parent: Ia
# Node: Ib has already been assigned parent: I
# Node: Ic has already been assigned parent: I
# Node: Ia/c has already been assigned parent: Ia
# Node: II P-97D has already been assigned parent: II Pec
# Node: IIn P has already been assigned parent: II P
# Node: IIn L has already been assigned parent: II L
# Node: IIn Pec has already been assigned parent: II Pec
# Node: TDE has already been assigned parent: TTypes
# /Users/marina/research/astro_research/code/thex_model/thex_data/data_clean.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[TARGET_LABEL] = df[TARGET_LABEL].apply(lambda x: int(cat_code[x]))
# Counts per Class
# ------------------
# Ia : 632
# II : 201
# II P : 69
# IIn : 40
# Ib : 29
# Ia Pec : 20
# Ia-91T : 19
# IIb : 18
# Ic : 15
# Ib/c : 11
# TDE : 7
# Ia-91bg : 5
# Ic BL : 3
# Ibn : 3
#
# Total: 1072
# PCA Analysis: Explained Variance Ratio
# [0.49105817 0.14238909 0.1161172  0.04804423 0.03534547]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9ba86e04aed5> in <module>
#      12          naive = False, # False -> Multi-dimensional kernel
#      13          )
# ---> 14 kde.run_model()
#
# ~/research/astro_research/code/thex_model/models/base_model/base_model.py in run_model(self)
#      54         print_features_used(col_list)
#      55         if data_filters['folds'] is not None:
# ---> 56             self.run_model_cv(col_list,  data_filters)
#      57             return self
#      58
#
# ~/research/astro_research/code/thex_model/models/base_model/base_model.py in run_model_cv(self, data_columns, data_filters)
#     222         for index_run in range(data_filters['num_runs']):
#     223             metrics, cur_rocs, ranged_metrics = self.run_cross_validation(
# --> 224                 k, X, y, data_filters)
#     225             class_metrics.append(metrics)
#     226             for class_code in unique_classes:
#
# ~/research/astro_research/code/thex_model/models/base_model/base_model.py in run_cross_validation(self, k, X, y, data_filters)
#     186
#     187             # Run model
# --> 188             self.train_model()
#     189             self.predictions = self.test_model()
#     190
#
# ~/research/astro_research/code/thex_model/models/kde_model/kde_model.py in train_model(self)
#      18
#      19     def train_model(self):
# ---> 20         self.summaries, self.priors = self.train()
#      21
#      22     def test_model(self):
#
# ~/research/astro_research/code/thex_model/models/kde_model/kde_train.py in train(self)
#      46                 # features at once
#      47                 summaries[class_code] = self.get_class_distribution(
# ---> 48                     instances, class_code)
#      49
#      50         return summaries, priors
#
# ~/research/astro_research/code/thex_model/models/kde_model/kde_train.py in get_class_distribution(self, X_class, class_code)
#      93         grid = GridSearchCV(
#      94             KernelDensity(), {'bandwidth': range_bws}, cv=3)
# ---> 95         grid.fit(X_class.values)
#      96         bw = grid.best_params_['bandwidth']
#      97         kde = KernelDensity(bandwidth=bw, kernel='gaussian', metric='euclidean')
#
# ~/research/astro_research/code/environments/thex_env/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# ~/research/astro_research/code/environments/thex_env/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     328                 ("Cannot have number of splits n_splits={0} greater"
#     329                  " than the number of samples: {1}.").format(self.n_splits,
# --> 330                                                              n_samples))
#     331
#     332         for train, test in super(_BaseKFold, self).split(X, y, groups):
#
# ValueError: Cannot have number of splits n_splits=3 greater than the number of samples: 2.
