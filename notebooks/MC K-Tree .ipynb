# %%
mag_cols = ['GALEXAIS_FUV', 'GALEXAIS_NUV', 
         'GALEXAIS_FUV.b', 'GALEXAIS_e_FUV.b', 'GALEXAIS_NUV.b',
        'GALEXAIS_e_NUV.b', 'GALEXAIS_FUV.a', 'GALEXAIS_e_FUV.a', 'GALEXAIS_NUV.a',
        'GALEXAIS_e_NUV.a', 'GALEXAIS_FUV.4', 'GALEXAIS_e_FUV.4', 'GALEXAIS_NUV.4', 
        'GALEXAIS_e_NUV.4', 'GALEXAIS_FUV.6', 'GALEXAIS_e_FUV.6', 'GALEXAIS_NUV.6', 
        'GALEXAIS_e_NUV.6',
        'AllWISE_W1mag', 'AllWISE_e_W1mag', 'AllWISE_W2mag', 'AllWISE_e_W2mag',
           'AllWISE_W3mag', 'AllWISE_e_W3mag', 'AllWISE_W4mag', 'AllWISE_e_W4mag', 
        'PS1_gmag' ,
        'PS1_gmagStd', 'PS1_b_gmag' ,'PS1_B_gmag',
        'PS1_gKmag' ,
        'PS1_rmag',
        'PS1_rmagStd', 'PS1_b_rmag' ,'PS1_B_rmag',
        'PS1_rKmag' ,
        'PS1_imag' ,
        'PS1_imagStd', 'PS1_b_imag', 'PS1_B_imag',
        'PS1_iKmag' ,
        'PS1_zmag' ,
        'PS1_zmagStd', 'PS1_b_zmag', 'PS1_B_zmag',
        'PS1_zKmag' ,
        'PS1_ymag',
        'PS1_ymagStd', 'PS1_b_ymag', 'PS1_B_ymag',
        'PS1_yKmag' 
]

flux_cols = ['GALEXAIS_Fflux', 'GALEXAIS_Nflux']

external_cols = ['AllWISE_Jmag', 'AllWISE_Hmag', 'AllWISE_Kmag']

source_size = ['GALEXAIS_Fima',
'GALEXAIS_Nima',
'GALEXAIS_Fr',
'GALEXAIS_Nr']

quality_photometry= ['AllWISE_snr1',
'AllWISE_chi2W1',
'AllWISE_snr2',
'AllWISE_chi2W2',
'AllWISE_snr3',
'AllWISE_chi2W3',
'AllWISE_snr4',
'AllWISE_chi2W4',
'AllWISE_chi2']
extinction_rates= ['GALEXAIS_E_B-V_',
'MWExt_FUV_PS' ,
'MWExt_NUV_PS' ,
'MWExt_FUV_Y',
'MWExt_NUV_Y',
'MWExt_u' ,
'MWExt_g' ,
'MWExt_r' ,
'MWExt_i' ,
'MWExt_z' ,
'MWExt_J' ,
'MWExt_H' ,
'MWExt_Ks' ,
'MWExt_W1' ,
'MWExt_W2' ,
'MWExt_W3' ,
'MWExt_W4' ]


cols = mag_cols + flux_cols + external_cols + source_size + quality_photometry + extinction_rates

# %%
from models.ktrees_model.ktrees_model import KTreesModel
# %matplotlib inline 
ktree = KTreesModel(
#          cols = cols,
         col_matches = ["SDSS", "GALEX", "WISE"],
         transform_features = True,
         incl_redshift = True,
         num_runs = 1,
         min_class_size = 6,
#          pca = 5,
#          subsample= 200,
        folds = 3,
         top_classes = 3, 
         naive = False)
ktree.run_model()


import warnings
warnings.filterwarnings('ignore')
# Out:
# Data Filters
# ------------------
# num_runs : 1
# test_on_train : False
# folds : 3
# data_split : 0.3
# top_classes : 3
# one_all : None
# subsample : None
# transform_features : True
# transform_labels : False
# incl_redshift : True
# min_class_size : 6
# pca : None
# naive : False
#
# Features
# ------------------
# NED_GALEX_FUV, NED_GALEX_NUV, NED_SDSS_u, NED_SDSS_g, NED_SDSS_r, NED_SDSS_i, NED_SDSS_z, AllWISE_W1mag, AllWISE_W2mag, AllWISE_W3mag, AllWISE_W4mag, AllWISE_Jmag, AllWISE_Hmag, AllWISE_Kmag, AllWISE_IsExtSrc
# first fold
# Tree brier_score_loss: -0.2870657721163944
# Class CC
# Tree brier_score_loss: -0.297364871039492
# Class I
# Tree brier_score_loss: -0.29913492582933887
# Class II
# Tree brier_score_loss: -0.10139171363417793
# Class II P
# Tree brier_score_loss: -0.3068095885451509
# Class Ia
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6ef77863db52> in <module>()
#      13          top_classes = 3,
#      14          naive = False)
# ---> 15 ktree.run_model()
#      16
#      17
#
# ~/research/astro_research/code/thex_model/models/base_model/base_model.py in run_model(self)
#      57         print_features_used(col_list)
#      58         if data_filters['folds'] is not None:
# ---> 59             self.run_model_cv(col_list,  data_filters)
#      60             return self
#      61
#
# ~/research/astro_research/code/thex_model/models/base_model_mc/mc_base_model.py in run_model_cv(self, data_columns, data_filters)
#     110         class_metrics = []
#     111         for index_run in range(data_filters['num_runs']):
# --> 112             roc_plots = self.run_cross_validation(k, X, y, data_filters)
#     113
#     114         for class_name in roc_plots.keys():
#
# ~/research/astro_research/code/thex_model/models/base_model_mc/mc_base_model.py in run_cross_validation(self, k, X, y, data_filters)
#      95
#      96             # Save ROC curve for each class
# ---> 97             roc_plots = self.save_roc_curve(i, roc_plots, model_classes)
#      98             i += 1
#      99         return roc_plots
#
# ~/research/astro_research/code/thex_model/models/base_model_mc/mc_base_model_plots.py in save_roc_curve(self, i, roc_plots, model_classes)
#      28                 column = class_probabilities[:, class_index]
#      29                 fpr, tpr, thresholds = roc_curve(
# ---> 30                     y_true=y_test_labels, y_score=column, sample_weight=None, drop_intermediate=True)
#      31                 # Updates FPR and TPR to nbe on the range 0 to 1 (for plotting)
#      32                 # Python directly alters list objects within dict.
#
# NameError: name 'y_test_labels' is not defined
